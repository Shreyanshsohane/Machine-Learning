# %%
import pandas as pd

# %%
df=pd.read_csv('https://media.githubusercontent.com/media/datablist/sample-csv-files/main/files/organizations/organizations-100.csv')

# %%
df.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
df.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
df.drop('Website',axis=1)
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                         Country  \
# 0              Papua New Guinea
# 1                       Finland
# 2                         China
# 3                  Turkmenistan
# 4                     Mauritius
# ..                          ...
# 95                     Ethiopia
# 96                     Anguilla
# 97  Falkland Islands (Malvinas)
# ...

# %%
df.head()  #permanent nai gaya
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
df.drop('Website',axis=1,inplace=True) # ab chala jaega permanently

# %%
df.head()
# Out:
#    Index  Organization Id                     Name           Country  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC  Papua New Guinea
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day           Finland
# 2      3  0bFED1ADAE4bcC1               Hester Ltd             China
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers      Turkmenistan
# 4      5  9eE8A6a4Eb96C24              Mayer Group         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# 4              Synchronized needs-based challenge     1991
#
#                       Industry  Number of employees
# 0                     Plastics                 3498
# 1  Glass / Ceramics / Concrete                 4952
# ...

# %%
df.set_index('Name')
# Out:
#                          Index  Organization Id                      Country  \
# Name
# Ferrell LLC                  1  FAB0d41d5b5d22c             Papua New Guinea
# Mckinney, Riley and Day      2  6A7EdDEA9FaDC52                      Finland
# Hester Ltd                   3  0bFED1ADAE4bcC1                        China
# Holder-Sellers               4  2bFC1Be8a4ce42f                 Turkmenistan
# Mayer Group                  5  9eE8A6a4Eb96C24                    Mauritius
# ...                        ...              ...                          ...
# Holmes Group                96  0a0bfFbBbB8eC7c                     Ethiopia
# Good Ltd                    97  BA6Cd9Dae2Efd62                     Anguilla
# Clements-Espinoza           98  E7df80C60Abd7f9  Falkland Islands (Malvinas)
# Mendez Inc                  99  AFc285dbE2fEd24              Kyrgyz Republic
# Watkins-Kaiser             100  e9eB5A60Cef8354                         Togo
#
# ...

# %%
df.head()
# Out:
#    Index  Organization Id                     Name           Country  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC  Papua New Guinea
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day           Finland
# 2      3  0bFED1ADAE4bcC1               Hester Ltd             China
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers      Turkmenistan
# 4      5  9eE8A6a4Eb96C24              Mayer Group         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# 4              Synchronized needs-based challenge     1991
#
#                       Industry  Number of employees
# 0                     Plastics                 3498
# 1  Glass / Ceramics / Concrete                 4952
# ...

# %%
d ={
    'Key1' : [1,3,4,5] ,
    'key2' : [2,3,5,3] ,
    'key3' : [1,3,5,7]
}

# %%
pd.DataFrame(d)
# Out:
#    Key1  key2  key3
# 0     1     2     1
# 1     3     3     3
# 2     4     5     5
# 3     5     3     7

# %%
df.dropna()  # jisme bhi NA hoga vo row udhadega
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                         Country  \
# 0              Papua New Guinea
# 1                       Finland
# 2                         China
# 3                  Turkmenistan
# 4                     Mauritius
# ..                          ...
# 95                     Ethiopia
# 96                     Anguilla
# 97  Falkland Islands (Malvinas)
# ...

# %%
g1 =  df.groupby('Industry')

# %%
g1.mean('Founded')  # '.T'  se data ko ghuma dega
# Out:
#                                 Index  Founded  Number of employees
# Industry
# Accounting                       74.0   1986.0               5004.0
# Alternative Dispute Resolution   82.0   2002.0               4044.0
# Architecture / Planning          19.0   1999.0               7961.0
# Arts / Crafts                    50.0   1997.5               2800.0
# Automotive                        4.0   2004.0                921.0
# ...                               ...      ...                  ...
# Utilities                        35.0   2020.0               2610.0
# Venture Capital / VC             34.0   1981.0               7443.0
# Wholesale                        21.0   1986.0               5010.0
# Wireless                         71.0   1982.0               6146.0
# Writing / Editing                41.0   2006.0               9067.0
#
# [72 rows x 3 columns]

# %%
df2 = df[0:5]

# %%
df3 = df[5:10]

# %%
df2
# Out:
#    Index  Organization Id                     Name           Country  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC  Papua New Guinea
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day           Finland
# 2      3  0bFED1ADAE4bcC1               Hester Ltd             China
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers      Turkmenistan
# 4      5  9eE8A6a4Eb96C24              Mayer Group         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# 4              Synchronized needs-based challenge     1991
#
#                       Industry  Number of employees
# 0                     Plastics                 3498
# 1  Glass / Ceramics / Concrete                 4952
# ...

# %%
df3
# Out:
#    Index  Organization Id            Name                            Country  \
# 5      6  cC757116fe1C085  Henry-Thompson                            Bahamas
# 6      7  219233e8aFF1BC3  Hansen-Everett                           Pakistan
# 7      8  ccc93DCF81a31CD   Mcintosh-Mora  Heard Island and McDonald Islands
# 8      9  0B4F93aA06ED03e        Carr Inc                             Kuwait
# 9     10  738b5aDe6B1C6A5      Gaines Inc                         Uzbekistan
#
#                                     Description  Founded  \
# 5  Face-to-face well-modulated customer loyalty     1992
# 6        Seamless disintermediate collaboration     2018
# 7      Centralized attitude-oriented capability     1970
# 8        Distributed impactful customer loyalty     1996
# 9               Multi-lateral scalable protocol     1997
#
#                         Industry  Number of employees
# 5  Primary / Secondary Education                 4914
# ...

# %%
df7 =pd.concat([df2,df3],axis=1)

# %%
df7.fillna("Nai hai")
# Out:
#      Index  Organization Id                     Name           Country  \
# 0      1.0  FAB0d41d5b5d22c              Ferrell LLC  Papua New Guinea
# 1      2.0  6A7EdDEA9FaDC52  Mckinney, Riley and Day           Finland
# 2      3.0  0bFED1ADAE4bcC1               Hester Ltd             China
# 3      4.0  2bFC1Be8a4ce42f           Holder-Sellers      Turkmenistan
# 4      5.0  9eE8A6a4Eb96C24              Mayer Group         Mauritius
# 5  Nai hai          Nai hai                  Nai hai           Nai hai
# 6  Nai hai          Nai hai                  Nai hai           Nai hai
# 7  Nai hai          Nai hai                  Nai hai           Nai hai
# 8  Nai hai          Nai hai                  Nai hai           Nai hai
# 9  Nai hai          Nai hai                  Nai hai           Nai hai
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase   1990.0
# 1             User-centric system-worthy leverage   2015.0
# ...

# %%
dict1 ={ 
    'key1' : [1,2,3,6,7],
    'key2' : [2,3,4,7,9],
    'key3' : [1,2,3,8,11]
}

# %%
dict2 ={ 
    'key1' : [1,2,3,5,7],
    'key2' : [1,3,5,8,9],
    'key3' : [11,12,14,19,111]
}

# %%
data1 =pd.DataFrame(dict1)

# %%
data2 =pd.DataFrame(dict2)

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     2     1
# 1     2     3     2
# 2     3     4     3
# 3     6     7     8
# 4     7     9    11

# %%
pd.merge(data1,data2)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3
# 0     1     2     1
# 1     2     3     2
# 2     3     4     3
# 3     6     7     8
# 4     7     9    11

# %%
# merge and join samaz nai aaya h firse dekho

# %%
df1=pd.read_csv('https://media.githubusercontent.com/media/datablist/sample-csv-files/main/files/organizations/organizations-100.csv')

# %%
df1.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
df1['Salary']= df1['Number of employees'].apply(lambda x : x*10000)

# %%
df1.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
def company_new_old(x) :
    if x>2000 :
        return "New"
    else :
        return "Old"

# %%
df1['Comapany_old_new'] =df1['Founded'].apply(company_new_old)

# %%
df1.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...
